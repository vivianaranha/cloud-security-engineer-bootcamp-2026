# %% [markdown]
# # Posture Score\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom cloud_security.posture import posture_score\nprint(posture_score({"iam":True,"logs":True,"backup":False}))
