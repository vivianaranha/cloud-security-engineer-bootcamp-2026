# %% [markdown]
# # Network Exposure\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom cloud_security.network import exposure_findings\nprint(exposure_findings({"source":"0.0.0.0/0","port":22}))
