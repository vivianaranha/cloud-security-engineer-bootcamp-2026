# %% [markdown]
# # IAM Review\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom cloud_security.iam import findings\nprint(findings({"actions":["*"],"mfa_required":False,"credential_type":"long_lived"}))
